# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet("/home/ed/Desktop/NYC_Taxi_Demand_Forecasting/Usecase4_Driver_Positioning_System/data/yellow_tripdata_2026-01.parquet")

df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2026-01-01 00:54:04   2026-01-01 00:59:37              1.0
# 1         1  2026-01-01 00:34:04   2026-01-01 00:39:47              0.0
# 2         1  2026-01-01 00:57:06   2026-01-01 01:05:59              0.0
# 3         2  2026-01-01 00:15:22   2026-01-01 00:58:10              4.0
# 4         2  2026-01-01 00:27:13   2026-01-01 00:40:43              0.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           239           238
# 1           0.90         1.0                  N           163           162
# 2           1.40         1.0                  N            43           237
# 3           5.58         1.0                  N           142           209
# 4           2.16         1.0                  N            88           144
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.shape
# Out:
# (3724889, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3724889 entries, 0 to 3724888
# Data columns (total 20 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
#  19  cbd_congestion_fee     float64
# ...

# %%
df.isnull().sum()
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count          1088058
# trip_distance                  0
# RatecodeID               1088058
# store_and_fwd_flag       1088058
# PULocationID                   0
# DOLocationID                   0
# payment_type                   0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          0
# total_amount                   0
# congestion_surcharge     1088058
# Airport_fee              1088058
# cbd_congestion_fee             0
# dtype: int64

# %% [markdown]
# ## 📌 Why This Step Matters
#
# Before building any model, we must understand:
#
# - Data quality (missing values, noise)
# - Feature availability
# - Data structure
# - Whether dataset supports prediction task
#
# Without this step, ML models will produce unreliable results.

# %%
df.describe()
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  3.724889e+06                     3724889                     3724889
# mean   1.873598e+00  2026-01-17 01:44:52.106518  2026-01-17 02:02:03.696138
# min    1.000000e+00         2025-12-31 23:57:29         2025-12-31 23:57:32
# 25%    2.000000e+00         2026-01-09 17:51:59         2026-01-09 18:08:47
# 50%    2.000000e+00         2026-01-16 21:20:56         2026-01-16 21:36:14
# 75%    2.000000e+00         2026-01-24 07:25:11         2026-01-24 07:40:22
# max    7.000000e+00         2026-02-01 00:45:01         2026-02-01 23:35:31
# std    7.014583e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     2.636831e+06   3.724889e+06  2.636831e+06  3.724889e+06
# mean      1.256271e+00   6.455647e+00  5.218853e+00  1.614372e+02
# min       0.000000e+00   0.000000e+00  1.000000e+00  1.000000e+00
# ...

# %%
print(df.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee',
#        'cbd_congestion_fee'],
#       dtype='object')

# %% [markdown]
# ## 🚖 Key Business Columns
#
# We focus on:
#
# - PULocationID → Where demand originates
# - pickup_datetime → When demand happens
# - fare_amount → Revenue generated
#
# These three variables define:
# 👉 Demand
# 👉 Time behavior
# 👉 Revenue potential

# %%
df = df.rename(columns={
    "tpep_pickup_datetime": "pickup_datetime",
    "tpep_dropoff_datetime": "dropoff_datetime"
})

# %%
df["pickup_datetime"] = pd.to_datetime(df["pickup_datetime"])

df["pickup_datetime"].min(), df["pickup_datetime"].max()
# Out:
# (Timestamp('2025-12-31 23:57:29'), Timestamp('2026-02-01 00:45:01'))

# %%
df["PULocationID"].value_counts().head(10)
# Out:
# PULocationID
# 237    160343
# 236    153640
# 132    152589
# 161    146641
# 186    110700
# 142    110004
# 162    108703
# 230    106114
# 79     100998
# 239     97465
# Name: count, dtype: int64

# %% [markdown]
# ## 🧠 Key Early Insights
#
# From initial analysis:
#
# - Demand is not uniform across zones
# - Certain zones dominate trip frequency
# - Time plays a critical role in demand variation
#
# This confirms:
# 👉 Location + Time are core drivers of demand

# %% [markdown]
# ## 🚀 Conclusion of Notebook 1
#
# In this notebook, we:
#
# ✔ Understood NYC taxi dataset structure
# ✔ Identified key variables affecting demand and revenue
# ✔ Confirmed that demand varies by location and time
# ✔ Established foundation for predictive modeling
#
# ### Next Step:
# We will perform feature engineering to convert raw data into ML-ready inputs for demand prediction.
