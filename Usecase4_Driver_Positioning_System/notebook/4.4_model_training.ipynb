# %% [markdown]
# # 🚖 NYC Taxi Demand Prediction System
#
# ## Notebook 4: Stable Model Training (Overfitting-Controlled)
#
# ### Objective
# Build a robust demand prediction model with:
# - Reduced overfitting
# - Stable validation-test performance
# - Proper regularization
# - Time-series safe evaluation
#
# ### Models
# - XGBoost (regularized)
# - Random Forest (controlled complexity)

# %%
import pandas as pd
import numpy as np

from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/ed/Desktop/NYC_Taxi_Demand_Forecasting/Usecase4_Driver_Positioning_System/data/zone_features.csv")

df = df.sort_values(["PULocationID", "hour"]).reset_index(drop=True)

print(df.shape)
df.head()
# Out:
# (5353, 19)
#    PULocationID  hour  demand  lag_1  lag_2  lag_3  rolling_mean_3  \
# 0             1     0       1    NaN    NaN    NaN             NaN
# 1             1     4       4    1.0    NaN    NaN             NaN
# 2             1     5       5    4.0    1.0    NaN        3.333333
# 3             1     6       2    5.0    4.0    1.0        3.666667
# 4             1     7       1    2.0    5.0    4.0        2.666667
#
#    rolling_std_3  zone_id  fare_mean   fare_std  total_trips  demand_norm  \
# 0            NaN        1  95.518803  46.608309          117     0.000086
# 1            NaN        1  95.518803  46.608309          117     0.000345
# 2       2.081666        1  95.518803  46.608309          117     0.000432
# 3       1.527525        1  95.518803  46.608309          117     0.000173
# 4       2.081666        1  95.518803  46.608309          117     0.000086
#
#    fare_norm  activity_norm  hour_sin      hour_cos       dow_sin   dow_cos
# ...

# %%
features = [
    "lag_1", "lag_2", "lag_3",
    "rolling_mean_3", "rolling_std_3",
    "hour_sin", "hour_cos",
    "dow_sin", "dow_cos",
    "fare_mean", "fare_std",
    "total_trips"
]

target = "demand"

# %%
print("Shape:", df.shape)
print(df.columns)
print(df[features].isna().sum())
# Out:
# Shape: (5353, 19)
# Index(['PULocationID', 'hour', 'demand', 'lag_1', 'lag_2', 'lag_3',
#        'rolling_mean_3', 'rolling_std_3', 'zone_id', 'fare_mean', 'fare_std',
#        'total_trips', 'demand_norm', 'fare_norm', 'activity_norm', 'hour_sin',
#        'hour_cos', 'dow_sin', 'dow_cos'],
#       dtype='object')
# lag_1             260
# lag_2             517
# lag_3             770
# rolling_mean_3    517
# rolling_std_3     517
# hour_sin            0
# hour_cos            0
# dow_sin             0
# dow_cos             0
# fare_mean           0
# fare_std            3
# total_trips         0
# dtype: int64

# %%
df = df.dropna(subset=features + [target]).reset_index(drop=True)

print("After cleaning:", df.shape)
# Out:
# After cleaning: (4583, 19)

# %%
df[features + [target]].isna().mean().sort_values(ascending=False)
# Out:
# lag_1             0.0
# lag_2             0.0
# lag_3             0.0
# rolling_mean_3    0.0
# rolling_std_3     0.0
# hour_sin          0.0
# hour_cos          0.0
# dow_sin           0.0
# dow_cos           0.0
# fare_mean         0.0
# fare_std          0.0
# total_trips       0.0
# demand            0.0
# dtype: float64

# %%
n = len(df)

train_end = int(n * 0.7)
val_end = int(n * 0.85)

train = df.iloc[:train_end]
val = df.iloc[train_end:val_end]
test = df.iloc[val_end:]

# %% [markdown]
# ## Why this split works better
#
# - Smaller train set prevents memorization
# - Larger test set gives realistic evaluation
# - Reduces validation optimism

# %%
print("Total dataset shape:", df.shape)
print("Train shape:", train.shape)
print("Val shape:", val.shape)
print("Test shape:", test.shape)
# Out:
# Total dataset shape: (4583, 19)
# Train shape: (3208, 19)
# Val shape: (687, 19)
# Test shape: (688, 19)

# %% [markdown]
# ## 📊 Why this split?
#
# We simulate real-world forecasting:
#
# - Train → learn patterns
# - Validation → tune models
# - Test → final unseen evaluation
#
# No leakage from future data.

# %%
X_train = train[features]
y_train = train[target]

X_val = val[features]
y_val = val[target]

X_test = test[features]
y_test = test[target]

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (3208, 12)
# (3208,)

# %%
xgb_model = XGBRegressor(
    n_estimators=400,
    learning_rate=0.03,
    max_depth=4,
    min_child_weight=5,
    subsample=0.7,
    colsample_bytree=0.7,
    reg_alpha=0.1,
    reg_lambda=1.0,
    random_state=42,
    n_jobs=-1
)

xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=5, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=400,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
rf_model = RandomForestRegressor(
    n_estimators=300,
    max_depth=10,
    min_samples_split=10,
    min_samples_leaf=4,
    random_state=42,
    n_jobs=-1
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_leaf=4, min_samples_split=10,
#                       n_estimators=300, n_jobs=-1, random_state=42)

# %%
def evaluate(name, model, X, y):
    pred = model.predict(X)
    mae = mean_absolute_error(y, pred)
    rmse = np.sqrt(mean_squared_error(y, pred))
    print(name)
    print("MAE :", mae)
    print("RMSE:", rmse)
    print("-"*30)
    return rmse

xgb_rmse = evaluate("XGBoost (Regularized)", xgb_model, X_val, y_val)
rf_rmse = evaluate("Random Forest (Controlled)", rf_model, X_val, y_val)
# Out:
# XGBoost (Regularized)
# MAE : 12.512127876281738
# RMSE: 28.23033335246692
# ------------------------------
# Random Forest (Controlled)
# MAE : 8.467006108360678
# RMSE: 29.056767486088038
# ------------------------------

# %%
final_model = xgb_model if xgb_rmse < rf_rmse else rf_model

print("Final Model:",
      "XGBoost" if final_model == xgb_model else "Random Forest")
# Out:
# Final Model: XGBoost

# %%
test_pred = final_model.predict(X_test)

test_mae = mean_absolute_error(y_test, test_pred)
test_rmse = np.sqrt(mean_squared_error(y_test, test_pred))

print("FINAL TEST MAE:", test_mae)
print("FINAL TEST RMSE:", test_rmse)
# Out:
# FINAL TEST MAE: 97.9267807006836
# FINAL TEST RMSE: 266.1643935146097

# %%
plt.figure()
plt.plot(y_test.values[:100], label="Actual")
plt.plot(test_pred[:100], label="Predicted")
plt.legend()
plt.title("Final Model Performance")
plt.show()

# %%
plt.figure()
plt.plot(y_test.values[:100], label="Actual")
plt.plot(test_pred[:100], label="Predicted")
plt.legend()
plt.title("Final Model Performance")
plt.show()

# %%
if final_model == xgb_model:
    from xgboost import plot_importance
    plot_importance(xgb_model)
    plt.title("XGBoost Feature Importance")
    plt.show()
else:
    import pandas as pd
    imp = pd.Series(rf_model.feature_importances_, index=features)
    imp.sort_values().plot(kind="barh")
    plt.title("Random Forest Feature Importance")
    plt.show()

# %%
import joblib
import json

# Save model
joblib.dump(final_model, "taxi_demand_model.pkl")

# Save feature list
with open("model_features.json", "w") as f:
    json.dump(features, f)

print("Model + features saved successfully!")
# Out:
# Model + features saved successfully!
